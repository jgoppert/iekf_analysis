# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import px4tools.ulog
import pandas
import os
import pickle
import scipy.interpolate
import px4tools.version

# %%
pandas.__version__
# Out:
# '0.19.99'

# %%
px4tools.version.git_revision
# Out:
# 'a7d187473ff1c9ef722c15da4a3f84919e73f682'

# %%
d_gyro = px4tools.ulog.cached_log_processing(
    log='./logs/19_19_32.ulg',
    msg_filter='sensor_gyro',
    processing_func=lambda x: x['sensor_gyro_0'].resample('1 s').agg('mean'),
    save_label='-gyro-0',
    force_processing=False)

# %%
px4tools.ulog.noise_analysis_sensor(d_gyro[:'2 h'], 'sensor_gyro_0')
# Out:
# {'sensor_gyro_0_randomwalk_correlation_time': [1076.7822044264758,
#   1664.2457366542826,
#   7657.1341717424157],
#  'sensor_gyro_0_sig_bi': [6.7100885678651517e-05,
#   3.1246908092147768e-05,
#   2.8807370463025332e-05],
#  'sensor_gyro_0_sig_rrw': [1.3872404042300187e-05,
#   3.2438848779713457e-06,
#   2.2541972829181283e-06],
#  'sensor_gyro_0_sig_rw': [8.313648699387914e-05,
#   6.7374090685732546e-05,
#   6.0526885111473206e-05],
#  'sensor_gyro_0_tau_0': [1.165847997260165,
#   3.0856324142873901,
#   2.1520414362531506],
#  'sensor_gyro_0_tau_1': [10.380076805513204,
#   35.973948697717219,
#   46.506861236760471],
#  'sensor_gyro_0_tau_2': [92.418561203145586,
#   419.40348400341162,
#   1005.0401937710947]}

# %%
d_accel = px4tools.ulog.cached_log_processing(
    log='/home/jgoppert/.ros/rootfs/fs/microsd/log/2017-01-06/00_00_36.ulg',
    mvi sg_filter='sensor_accel',
    processing_func=lambda x: x['sensor_accel_0'].resample('1 s').agg('mean'),
    save_label='-accel-0',
    force_processing=True)
px4tools.ulog.noise_analysis_sensor(d_accel, 'sensor_accel_0')
# Out:
# failed to find tau_2
# failed to find tau_2
# {'sensor_accel_0_randomwalk_correlation_time': [132.44251329354984,
#   123.45491563344717,
#   327.57013367860418],
#  'sensor_accel_0_sig_bi': [0.0080501184809861261,
#   0.0084227754083746956,
#   0.0088200067979319081],
#  'sensor_accel_0_sig_rrw': [nan, nan, 0.0039533423521215631],
#  'sensor_accel_0_sig_rw': [0.0053475525904992218,
#   0.0055951020547873685,
#   0.0058589759035104078],
#  'sensor_accel_0_tau_0': [1, 1, 1],
#  'sensor_accel_0_tau_1': [1, 1, 1],
#  'sensor_accel_0_tau_2': [nan, nan, 1148.2049658914314]}

# %%
d_accel.t_sensor_accel_0__f_x.plot()
d_accel.t_sensor_accel_0__f_y.plot()
d_accel.t_sensor_accel_0__f_z.plot()
