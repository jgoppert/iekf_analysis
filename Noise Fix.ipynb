# %%
# %pylab inline
import px4tools
import pandas
import os
import pickle
import scipy.interpolate
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import px4tools.version
px4tools.version.git_revision
# Out:
# 'cd917e19bb64e7913b18872ca9adbd2e865837e7'

# %% [markdown]
# ## SITL Modified Noise Model

# %%
d0 = px4tools.ulog.read_ulog('./logs/13_36_37.ulg')

# %%
px4tools.ulog.

# %% [markdown]
# ## Real data from Pixhawk 2

# %%
d = px4tools.ulog.read_ulog('./logs/01-03-17-mhkabir-pixhawk2.ulg',
                           messages='sensor_combined').resample_and_concat()
px4tools.ulog.noise_analysis(d)
# Out:
# merging sensor_combined_0 as of timestamp
# {'accelerometer_bias_instability': array([ 0.00173878,  0.00095417,  0.00335572]),
#  'accelerometer_bias_randomwalk': array([  8.73751426e-05,   3.09328349e-05,   2.38631148e-04]),
#  'accelerometer_bias_tau_0': array([ 1.58828152,  1.65208839,  1.31728349]),
#  'accelerometer_bias_tau_1': array([ 356.54225091,  821.96553332,  164.24145788]),
#  'accelerometer_bias_tau_2': array([  768.55300964,  1885.26997426,   405.1067084 ]),
#  'accelerometer_noise_density': array([ 0.01507022,  0.01309254,  0.02057544]),
#  'accelerometer_randomwalk_correlation_time': [1519.4071413466957,
#   4805.2831462199565,
#   2133.7090258162252],
#  'baro_bias_instability': 0.16365569044437733,
#  'baro_bias_randomwalk': 0.037211370200519497,
#  'baro_bias_tau_0': 1.7050560254094278,
#  'baro_bias_tau_1': 14.608474402162008,
#  'baro_bias_tau_2': 46.115491185991161,
#  'baro_noise_density': 0.31546289316494014,
# ...
